# %% [markdown]
# # Speech to Text with Open AI Whisper

# %%
# %pip install -U openai-whisper

# %%
import gradio as gr
import numpy as np
import pytube
import time
import sys
import whisper

# %%
sys.version
# Out:
# '3.10.10 (main, Mar 21 2023, 18:45:11) [GCC 11.2.0]'

# %% [markdown]
# ## Download a YouTube audio mp4 file

# %%
video = "https://www.youtube.com/watch?v=mRTqaC04T04"

yt = pytube.YouTube(video)
audio = yt.streams.get_audio_only()
audio.download()
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/standardd14sr/code/Users/seretkow/Speech to text/Sur les routes de linnovation - Economie Circulaire - Déchetterie commune POINTP.mp4'

# %%
os.rename(
    "Sur les routes de linnovation - Economie Circulaire - Déchetterie commune POINTP.mp4",
    "audio.mp4",
)

# %% [markdown]
# ## Base model

# %%
model = whisper.load_model("base")

# %%
print(
    f"Model is {'multilingual' if model.is_multilingual else 'English-only'} "
    f"and has {sum(np.prod(p.shape) for p in model.parameters()):,} parameters."
)
# Out:
# Model is multilingual and has 71,825,920 parameters.

# %%
model
# Out:
# Whisper(
#   (encoder): AudioEncoder(
#     (conv1): Conv1d(80, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#     (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(2,), padding=(1,))
#     (blocks): ModuleList(
#       (0-5): 6 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=False)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (out): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (attn_ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (mlp_ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln_post): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TextDecoder(
#     (token_embedding): Embedding(51865, 512)
#     (blocks): ModuleList(
#       (0-5): 6 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=False)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (out): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (attn_ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (cross_attn): MultiHeadAttention(
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=False)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (out): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (cross_attn_ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (mlp_ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("audio.mp4")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# %%
# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")
print(f"Confidence = {max(probs.values())}")
# Out:
# Detected language: fr
# Confidence = 0.9830532670021057

# %% [markdown]
# ## Extract mp3 audio file from the audio mp4

# %%
from moviepy.editor import AudioFileClip

# Load the audio file
audio = AudioFileClip("audio.mp4")
sample = audio.subclip(20, 100)

# Save the new audio file
sample.write_audiofile("audio.mp3")
# Out:
# ALSA lib confmisc.c:767:(parse_card) cannot find card '0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_card_driver returned error: No such file or directory
# ALSA lib confmisc.c:392:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1246:(snd_func_refer) error evaluating name
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:767:(parse_card) cannot find card '0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_card_driver returned error: No such file or directory
# ALSA lib confmisc.c:392:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1246:(snd_func_refer) error evaluating name
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM default
# MoviePy - Writing audio in audio.mp3
# MoviePy - Done.

# %%
sample.write_audiofile("audio.wav")
# Out:
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.

# %%
from IPython.display import Audio

Audio("audio.mp3", autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start = time.time()
text_base = model.transcribe("audio.mp3")
elapsed = time.time() - start
print(
    "Elapsed time: "
    + time.strftime(
        "%H:%M:%S.{}".format(str(elapsed % 1)[2:])[:15], time.gmtime(elapsed)
    )
)
# Out:
# Elapsed time: 00:00:07.922408

# %%
from pprint import pprint

pprint(text_base, indent=2, width=30)
# Out:
# { 'language': 'fr',
#   'segments': [ { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 1.0,
#                   'id': 0,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 0.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Bonjour '
#                           'Patrick '
#                           '!',
#                   'tokens': [ 50364,
#                               25431,
#                               13980,
#                               2298,
#                               50414]},
#                 { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 2.0,
#                   'id': 1,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 1.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Bonjour '
#                           '!',
#                   'tokens': [ 50414,
#                               25431,
#                               2298,
#                               50464]},
#                 { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 5.0,
#                   'id': 2,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 2.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Alors '
#                           'vous '
#                           'êtes '
#                           'le '
#                           'responsable '
#                           'de '
#                           'ce '
#                           'centre '
#                           'de '
#                           'collecte, '
#                           'comment '
#                           'va '
#                           "l'activité "
#                           '?',
#                   'tokens': [ 50464,
#                               9946,
#                               2630,
#                               18935,
#                               476,
#                               2914,
#                               712,
#                               368,
#                               1769,
#                               10093,
#                               368,
#                               2500,
#                               68,
#                               11,
#                               2871,
#                               2773,
#                               287,
#                               6,
#                               23397,
#                               5066,
#                               2506,
#                               50614]},
#                 { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 9.0,
#                   'id': 3,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 5.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'La '
#                           'activité '
#                           'va '
#                           'très '
#                           'bien, '
#                           "c'est "
#                           'vraiment '
#                           'satisfait '
#                           'et '
#                           'le '
#                           'val '
#                           'et '
#                           'client '
#                           'avec '
#                           'le '
#                           'sourire.',
#                   'tokens': [ 50614,
#                               2369,
#                               2430,
#                               5066,
#                               2773,
#                               5732,
#                               3610,
#                               11,
#                               269,
#                               6,
#                               377,
#                               8322,
#                               5519,
#                               1001,
#                               1030,
#                               476,
#                               1323,
#                               1030,
#                               6423,
#                               4163,
#                               476,
#                               11006,
#                               621,
#                               13,
#                               50814]},
#                 { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 13.0,
#                   'id': 4,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 9.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           "C'est "
#                           'content '
#                           'de '
#                           'la '
#                           'prestation '
#                           'que '
#                           'vous '
#                           'offrez, '
#                           'ils '
#                           'sont '
#                           'satisfaits '
#                           'aussi '
#                           'des '
#                           'plages '
#                           "d'ouverture",
#                   'tokens': [ 50814,
#                               383,
#                               6,
#                               377,
#                               2701,
#                               368,
#                               635,
#                               16305,
#                               399,
#                               631,
#                               2630,
#                               766,
#                               17693,
#                               11,
#                               9047,
#                               4900,
#                               5519,
#                               1001,
#                               82,
#                               6212,
#                               730,
#                               499,
#                               1660,
#                               274,
#                               6,
#                               43315,
#                               540,
#                               51014]},
#                 { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 16.0,
#                   'id': 5,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 13.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'et '
#                           'des '
#                           'types '
#                           'de '
#                           'filières '
#                           'que '
#                           'vous '
#                           'leur '
#                           'proposer.',
#                   'tokens': [ 51014,
#                               1030,
#                               730,
#                               3467,
#                               368,
#                               1387,
#                               39408,
#                               631,
#                               2630,
#                               9580,
#                               7532,
#                               260,
#                               13,
#                               51164]},
#                 { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 21.0,
#                   'id': 6,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 16.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Les '
#                           'clients '
#                           'sont '
#                           'hyper '
#                           'satisfaits, '
#                           'je '
#                           'sais '
#                           'aussi '
#                           'que '
#                           'mes '
#                           'agents '
#                           'sont '
#                           'vraiment '
#                           'satisfaits '
#                           'de '
#                           'venir '
#                           'travailler '
#                           'ici '
#                           'tous '
#                           'les '
#                           'matins.',
#                   'tokens': [ 51164,
#                               6965,
#                               6982,
#                               4900,
#                               9848,
#                               5519,
#                               1001,
#                               82,
#                               11,
#                               1506,
#                               11757,
#                               6212,
#                               631,
#                               3813,
#                               12554,
#                               4900,
#                               8322,
#                               5519,
#                               1001,
#                               82,
#                               368,
#                               20817,
#                               30968,
#                               11575,
#                               8317,
#                               1512,
#                               3803,
#                               1292,
#                               13,
#                               51414]},
#                 { 'avg_logprob': -0.2834169968314793,
#                   'compression_ratio': 1.7526132404181185,
#                   'end': 25.0,
#                   'id': 7,
#                   'no_speech_prob': 0.12293168157339096,
#                   'seek': 0,
#                   'start': 24.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Bonjour '
#                           'à '
#                           'tous '
#                           'les '
#                           'deux.',
#                   'tokens': [ 51564,
#                               25431,
#                               1531,
#                               8317,
#                               1512,
#                               8208,
#                               13,
#                               51614]},
#                 { 'avg_logprob': -0.27904279969579027,
#                   'compression_ratio': 1.6179401993355482,
#                   'end': 30.0,
#                   'id': 8,
#                   'no_speech_prob': 0.22202426195144653,
#                   'seek': 2500,
#                   'start': 25.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Dis-t-nous '
#                           'en '
#                           'quoi '
#                           'le '
#                           'service '
#                           'au '
#                           'fer '
#                           'par '
#                           'cette '
#                           'déchétrie '
#                           'vous '
#                           'aide '
#                           'aux '
#                           'clients '
#                           'dans '
#                           'votre '
#                           'métier '
#                           '?',
#                   'tokens': [ 50364,
#                               4208,
#                               12,
#                               83,
#                               12,
#                               47008,
#                               465,
#                               11714,
#                               476,
#                               2643,
#                               1609,
#                               7202,
#                               971,
#                               5550,
#                               2795,
#                               339,
#                               4051,
#                               5469,
#                               2630,
#                               40890,
#                               7865,
#                               6982,
#                               2680,
#                               10087,
#                               20275,
#                               811,
#                               2506,
#                               50614]},
#                 { 'avg_logprob': -0.27904279969579027,
#                   'compression_ratio': 1.6179401993355482,
#                   'end': 35.0,
#                   'id': 9,
#                   'no_speech_prob': 0.22202426195144653,
#                   'seek': 2500,
#                   'start': 30.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'On '
#                           'est '
#                           'spécialisé '
#                           'dans '
#                           'la '
#                           'innovation, '
#                           'ce '
#                           'qui '
#                           'nous '
#                           'intéresse, '
#                           "c'est "
#                           'de '
#                           'pouvoir '
#                           'tout '
#                           'mélanger',
#                   'tokens': [ 50614,
#                               1282,
#                               871,
#                               34141,
#                               22118,
#                               2680,
#                               635,
#                               8504,
#                               11,
#                               1769,
#                               1956,
#                               4666,
#                               18555,
#                               22603,
#                               11,
#                               269,
#                               6,
#                               377,
#                               368,
#                               14874,
#                               3486,
#                               41953,
#                               3176,
#                               50864]},
#                 { 'avg_logprob': -0.27904279969579027,
#                   'compression_ratio': 1.6179401993355482,
#                   'end': 42.0,
#                   'id': 10,
#                   'no_speech_prob': 0.22202426195144653,
#                   'seek': 2500,
#                   'start': 35.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'et '
#                           'puis '
#                           'venir '
#                           'ici '
#                           'faire '
#                           'le '
#                           'tri '
#                           'et '
#                           'un '
#                           'gain '
#                           'de '
#                           'temps '
#                           'énorme, '
#                           'de '
#                           'pouvoir '
#                           'recharger '
#                           'nos '
#                           'camions, '
#                           'racheter.',
#                   'tokens': [ 50864,
#                               1030,
#                               9093,
#                               20817,
#                               11575,
#                               4865,
#                               476,
#                               1376,
#                               1030,
#                               517,
#                               6052,
#                               368,
#                               8827,
#                               27982,
#                               68,
#                               11,
#                               368,
#                               14874,
#                               319,
#                               48942,
#                               3269,
#                               1945,
#                               626,
#                               11,
#                               367,
#                               608,
#                               2398,
#                               13,
#                               51214]},
#                 { 'avg_logprob': -0.27904279969579027,
#                   'compression_ratio': 1.6179401993355482,
#                   'end': 45.0,
#                   'id': 11,
#                   'no_speech_prob': 0.22202426195144653,
#                   'seek': 2500,
#                   'start': 42.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Et '
#                           'oui '
#                           'parce '
#                           'que '
#                           'cette '
#                           'déchétrie '
#                           'est '
#                           'partagée '
#                           'entre '
#                           'point '
#                           'P '
#                           'et '
#                           'la '
#                           'plateforme '
#                           '?',
#                   'tokens': [ 51214,
#                               3790,
#                               14367,
#                               6992,
#                               631,
#                               5550,
#                               2795,
#                               339,
#                               4051,
#                               5469,
#                               871,
#                               644,
#                               559,
#                               3856,
#                               3962,
#                               935,
#                               430,
#                               1030,
#                               635,
#                               5924,
#                               44562,
#                               2506,
#                               51364]},
#                 { 'avg_logprob': -0.27904279969579027,
#                   'compression_ratio': 1.6179401993355482,
#                   'end': 46.0,
#                   'id': 12,
#                   'no_speech_prob': 0.22202426195144653,
#                   'seek': 2500,
#                   'start': 45.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Tout '
#                           'à '
#                           'fait, '
#                           'oui, '
#                           'voilà.',
#                   'tokens': [ 51364,
#                               20453,
#                               1531,
#                               3887,
#                               11,
#                               14367,
#                               11,
#                               14624,
#                               13,
#                               51414]},
#                 { 'avg_logprob': -0.27904279969579027,
#                   'compression_ratio': 1.6179401993355482,
#                   'end': 51.0,
#                   'id': 13,
#                   'no_speech_prob': 0.22202426195144653,
#                   'seek': 2500,
#                   'start': 46.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           "C'est "
#                           'très '
#                           'convétitif, '
#                           'puisque '
#                           'comme '
#                           'il '
#                           'y '
#                           'a '
#                           'des '
#                           'parties '
#                           'qui '
#                           'sont '
#                           'gratuite.',
#                   'tokens': [ 51414,
#                               383,
#                               6,
#                               377,
#                               5732,
#                               3754,
#                               4051,
#                               270,
#                               351,
#                               11,
#                               28090,
#                               5173,
#                               1930,
#                               288,
#                               257,
#                               730,
#                               8265,
#                               1956,
#                               4900,
#                               10158,
#                               21681,
#                               13,
#                               51664]},
#                 { 'avg_logprob': -0.36570547811640136,
#                   'compression_ratio': 1.8297213622291022,
#                   'end': 59.0,
#                   'id': 14,
#                   'no_speech_prob': 0.043968986719846725,
#                   'seek': 5100,
#                   'start': 52.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'On '
#                           'utilise '
#                           'beaucoup '
#                           'parce '
#                           'que '
#                           'ça '
#                           'nous '
#                           'aide '
#                           'à '
#                           'être '
#                           'rapide '
#                           'et '
#                           'efficace, '
#                           'on '
#                           'est '
#                           'très '
#                           'content '
#                           'parce '
#                           'que '
#                           "c'est "
#                           'facile '
#                           "d'accé",
#                   'tokens': [ 50414,
#                               1282,
#                               39475,
#                               8796,
#                               6992,
#                               631,
#                               2788,
#                               4666,
#                               40890,
#                               1531,
#                               7418,
#                               5099,
#                               482,
#                               1030,
#                               4703,
#                               617,
#                               11,
#                               322,
#                               871,
#                               5732,
#                               2701,
#                               6992,
#                               631,
#                               269,
#                               6,
#                               377,
#                               23670,
#                               274,
#                               6,
#                               8476,
#                               526,
#                               50764]},
#                 { 'avg_logprob': -0.36570547811640136,
#                   'compression_ratio': 1.8297213622291022,
#                   'end': 64.0,
#                   'id': 15,
#                   'no_speech_prob': 0.043968986719846725,
#                   'seek': 5100,
#                   'start': 59.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'et '
#                           'parce '
#                           'que '
#                           'ça '
#                           'veut '
#                           'être '
#                           'tard '
#                           'au '
#                           'jour '
#                           'que '
#                           "l'avant-à-avant "
#                           'le '
#                           'soir, '
#                           'ça '
#                           'nous '
#                           'aide '
#                           'beaucoup '
#                           'au '
#                           'niveau '
#                           'de '
#                           'organisation '
#                           'et '
#                           'tout '
#                           'ça.',
#                   'tokens': [ 50764,
#                               1030,
#                               6992,
#                               631,
#                               2788,
#                               14873,
#                               7418,
#                               21057,
#                               1609,
#                               2827,
#                               631,
#                               287,
#                               6,
#                               35034,
#                               12,
#                               1467,
#                               12,
#                               35034,
#                               476,
#                               27105,
#                               11,
#                               2788,
#                               4666,
#                               40890,
#                               8796,
#                               1609,
#                               19144,
#                               368,
#                               18641,
#                               1030,
#                               3486,
#                               2788,
#                               13,
#                               51014]},
#                 { 'avg_logprob': -0.36570547811640136,
#                   'compression_ratio': 1.8297213622291022,
#                   'end': 67.0,
#                   'id': 16,
#                   'no_speech_prob': 0.043968986719846725,
#                   'seek': 5100,
#                   'start': 64.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           "C'est "
#                           'très '
#                           'important '
#                           'de '
#                           'faire '
#                           'le '
#                           'tri '
#                           'pour '
#                           "l'avenir, "
#                           'pour '
#                           'la '
#                           'planète.',
#                   'tokens': [ 51014,
#                               383,
#                               6,
#                               377,
#                               5732,
#                               1021,
#                               368,
#                               4865,
#                               476,
#                               1376,
#                               2016,
#                               287,
#                               6,
#                               4940,
#                               347,
#                               11,
#                               2016,
#                               635,
#                               1393,
#                               22279,
#                               13,
#                               51164]},
#                 { 'avg_logprob': -0.36570547811640136,
#                   'compression_ratio': 1.8297213622291022,
#                   'end': 72.0,
#                   'id': 17,
#                   'no_speech_prob': 0.043968986719846725,
#                   'seek': 5100,
#                   'start': 67.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'En '
#                           'plus '
#                           'maintenant, '
#                           'on '
#                           'a '
#                           'une '
#                           'obligation '
#                           'au '
#                           'niveau '
#                           'de '
#                           'nos '
#                           'clients '
#                           'depuis '
#                           'plus '
#                           "d'un "
#                           'an, '
#                           'maintenant '
#                           'on '
#                           'a '
#                           'présenté '
#                           'le '
#                           'traitement '
#                           'des '
#                           'déchets.',
#                   'tokens': [ 51164,
#                               2193,
#                               1804,
#                               14817,
#                               11,
#                               322,
#                               257,
#                               2251,
#                               20326,
#                               1609,
#                               19144,
#                               368,
#                               3269,
#                               6982,
#                               16062,
#                               1804,
#                               274,
#                               6,
#                               409,
#                               364,
#                               11,
#                               14817,
#                               322,
#                               257,
#                               26056,
#                               526,
#                               476,
#                               22538,
#                               1712,
#                               730,
#                               2795,
#                               339,
#                               1385,
#                               13,
#                               51414]},
#                 { 'avg_logprob': -0.36570547811640136,
#                   'compression_ratio': 1.8297213622291022,
#                   'end': 74.0,
#                   'id': 18,
#                   'no_speech_prob': 0.043968986719846725,
#                   'seek': 5100,
#                   'start': 72.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Donc '
#                           "c'est "
#                           'très '
#                           'important '
#                           'pour '
#                           'nous.',
#                   'tokens': [ 51414,
#                               7477,
#                               269,
#                               6,
#                               377,
#                               5732,
#                               1021,
#                               2016,
#                               4666,
#                               13,
#                               51514]},
#                 { 'avg_logprob': -0.36570547811640136,
#                   'compression_ratio': 1.8297213622291022,
#                   'end': 79.0,
#                   'id': 19,
#                   'no_speech_prob': 0.043968986719846725,
#                   'seek': 5100,
#                   'start': 74.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Même '
#                           'la '
#                           'terre '
#                           'qui '
#                           "n'a "
#                           'pas '
#                           'de '
#                           'coup, '
#                           'ils '
#                           'nous '
#                           'le '
#                           'prennent '
#                           'aussi '
#                           'pour '
#                           'voir '
#                           'le '
#                           'vidéo.',
#                   'tokens': [ 51514,
#                               42027,
#                               635,
#                               31815,
#                               1956,
#                               297,
#                               6,
#                               64,
#                               1736,
#                               368,
#                               8682,
#                               11,
#                               9047,
#                               4666,
#                               476,
#                               43149,
#                               17469,
#                               6212,
#                               2016,
#                               10695,
#                               476,
#                               11660,
#                               13,
#                               51764]}],
#   'text': ' Bonjour Patrick '
#           '! Bonjour ! Alors '
#           'vous êtes le '
#           'responsable de ce '
#           'centre de '
#           'collecte, comment '
#           "va l'activité ? "
#           'La activité va '
#           "très bien, c'est "
#           'vraiment '
#           'satisfait et le '
#           'val et client '
#           'avec le sourire. '
#           "C'est content de "
#           'la prestation que '
#           'vous offrez, ils '
#           'sont satisfaits '
#           'aussi des plages '
#           "d'ouverture et "
#           'des types de '
#           'filières que vous '
#           'leur proposer. '
#           'Les clients sont '
#           'hyper satisfaits, '
#           'je sais aussi que '
#           'mes agents sont '
#           'vraiment '
#           'satisfaits de '
#           'venir travailler '
#           'ici tous les '
#           'matins. Bonjour à '
#           'tous les deux. '
#           'Dis-t-nous en '
#           'quoi le service '
#           'au fer par cette '
#           'déchétrie vous '
#           'aide aux clients '
#           'dans votre métier '
#           '? On est '
#           'spécialisé dans '
#           'la innovation, ce '
#           'qui nous '
#           "intéresse, c'est "
#           'de pouvoir tout '
#           'mélanger et puis '
#           'venir ici faire '
#           'le tri et un gain '
#           'de temps énorme, '
#           'de pouvoir '
#           'recharger nos '
#           'camions, '
#           'racheter. Et oui '
#           'parce que cette '
#           'déchétrie est '
#           'partagée entre '
#           'point P et la '
#           'plateforme ? Tout '
#           'à fait, oui, '
#           "voilà. C'est très "
#           'convétitif, '
#           'puisque comme il '
#           'y a des parties '
#           'qui sont '
#           'gratuite. On '
#           'utilise beaucoup '
#           'parce que ça nous '
#           'aide à être '
#           'rapide et '
#           'efficace, on est '
#           'très content '
#           "parce que c'est "
#           "facile d'accé et "
#           'parce que ça veut '
#           'être tard au jour '
#           'que '
#           "l'avant-à-avant "
#           'le soir, ça nous '
#           'aide beaucoup au '
#           'niveau de '
#           'organisation et '
#           "tout ça. C'est "
#           'très important de '
#           'faire le tri pour '
#           "l'avenir, pour la "
#           'planète. En plus '
#           'maintenant, on a '
#           'une obligation au '
#           'niveau de nos '
#           'clients depuis '
#           "plus d'un an, "
#           'maintenant on a '
#           'présenté le '
#           'traitement des '
#           'déchets. Donc '
#           "c'est très "
#           'important pour '
#           'nous. Même la '
#           "terre qui n'a pas "
#           'de coup, ils nous '
#           'le prennent aussi '
#           'pour voir le '
#           'vidéo.'}

# %%
text_base["text"]
# Out:
# " Bonjour Patrick ! Bonjour ! Alors vous êtes le responsable de ce centre de collecte, comment va l'activité ? La activité va très bien, c'est vraiment satisfait et le val et client avec le sourire. C'est content de la prestation que vous offrez, ils sont satisfaits aussi des plages d'ouverture et des types de filières que vous leur proposer. Les clients sont hyper satisfaits, je sais aussi que mes agents sont vraiment satisfaits de venir travailler ici tous les matins. Bonjour à tous les deux. Dis-t-nous en quoi le service au fer par cette déchétrie vous aide aux clients dans votre métier ? On est spécialisé dans la innovation, ce qui nous intéresse, c'est de pouvoir tout mélanger et puis venir ici faire le tri et un gain de temps énorme, de pouvoir recharger nos camions, racheter. Et oui parce que cette déchétrie est partagée entre point P et la plateforme ? Tout à fait, oui, voilà. C'est très convétitif, puisque comme il y a des parties qui sont gratuite. On utilise beaucoup parce que ça nous aide à être rapide et efficace, on est très content parce que c'est facile d'accé et parce que ça veut être tard au jour que l'avant-à-avant le soir, ça nous aide beaucoup au niveau de organisation et tout ça. C'est très important de faire le tri pour l'avenir, pour la planète. En plus maintenant, on a une obligation au niveau de nos clients depuis plus d'un an, maintenant on a présenté le traitement des déchets. Donc c'est très important pour nous. Même la terre qui n'a pas de coup, ils nous le prennent aussi pour voir le vidéo."

# %% [markdown]
# ## Large model

# %%
# Loading large model
model = whisper.load_model("large")

# %%
print(
    f"Model is {'multilingual' if model.is_multilingual else 'English-only'} "
    f"and has {sum(np.prod(p.shape) for p in model.parameters()):,} parameters."
)
# Out:
# Model is multilingual and has 1,541,384,960 parameters.

# %%
model
# Out:
# Whisper(
#   (encoder): AudioEncoder(
#     (conv1): Conv1d(80, 1280, kernel_size=(3,), stride=(1,), padding=(1,))
#     (conv2): Conv1d(1280, 1280, kernel_size=(3,), stride=(2,), padding=(1,))
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln_post): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TextDecoder(
#     (token_embedding): Embedding(51865, 1280)
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (cross_attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (cross_attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
start = time.time()
text_large = model.transcribe("audio.mp3")
elapsed = time.time() - start
print(
    "Elapsed time: "
    + time.strftime(
        "%H:%M:%S.{}".format(str(elapsed % 1)[2:])[:15], time.gmtime(elapsed)
    )
)
# Out:
# Elapsed time: 00:01:18.523413

# %%
pprint(text_large, indent=2, width=30)
# Out:
# { 'language': 'fr',
#   'segments': [ { 'avg_logprob': -0.23453645408153534,
#                   'compression_ratio': 1.7288732394366197,
#                   'end': 1.0,
#                   'id': 0,
#                   'no_speech_prob': 0.022877629846334457,
#                   'seek': 0,
#                   'start': 0.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Bonjour '
#                           'Patrick '
#                           '!',
#                   'tokens': [ 50364,
#                               25431,
#                               13980,
#                               2298,
#                               50414]},
#                 { 'avg_logprob': -0.23453645408153534,
#                   'compression_ratio': 1.7288732394366197,
#                   'end': 2.0,
#                   'id': 1,
#                   'no_speech_prob': 0.022877629846334457,
#                   'seek': 0,
#                   'start': 1.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Bonjour '
#                           '!',
#                   'tokens': [ 50414,
#                               25431,
#                               2298,
#                               50464]},
#                 { 'avg_logprob': -0.23453645408153534,
#                   'compression_ratio': 1.7288732394366197,
#                   'end': 5.0,
#                   'id': 2,
#                   'no_speech_prob': 0.022877629846334457,
#                   'seek': 0,
#                   'start': 2.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Alors '
#                           'vous '
#                           'êtes '
#                           'le '
#                           'responsable '
#                           'de '
#                           'ce '
#                           'centre '
#                           'de '
#                           'collecte, '
#                           'comment '
#                           'va '
#                           "l'activité "
#                           '?',
#                   'tokens': [ 50464,
#                               9946,
#                               2630,
#                               18935,
#                               476,
#                               2914,
#                               712,
#                               368,
#                               1769,
#                               10093,
#                               368,
#                               2500,
#                               68,
#                               11,
#                               2871,
#                               2773,
#                               287,
#                               6,
#                               23397,
#                               5066,
#                               2506,
#                               50614]},
#                 { 'avg_logprob': -0.23453645408153534,
#                   'compression_ratio': 1.7288732394366197,
#                   'end': 9.0,
#                   'id': 3,
#                   'no_speech_prob': 0.022877629846334457,
#                   'seek': 0,
#                   'start': 5.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           "L'activité "
#                           'va '
#                           'très '
#                           'bien, '
#                           'je '
#                           'suis '
#                           'vraiment '
#                           'satisfait '
#                           'de '
#                           'voir '
#                           'les '
#                           'clients '
#                           'avec '
#                           'le '
#                           'sourire.',
#                   'tokens': [ 50614,
#                               441,
#                               6,
#                               23397,
#                               5066,
#                               2773,
#                               5732,
#                               3610,
#                               11,
#                               1506,
#                               7624,
#                               8322,
#                               5519,
#                               1001,
#                               368,
#                               10695,
#                               1512,
#                               6982,
#                               4163,
#                               476,
#                               11006,
#                               621,
#                               13,
#                               50814]},
#                 { 'avg_logprob': -0.23453645408153534,
#                   'compression_ratio': 1.7288732394366197,
#                   'end': 16.0,
#                   'id': 4,
#                   'no_speech_prob': 0.022877629846334457,
#                   'seek': 0,
#                   'start': 9.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Vous '
#                           'êtes '
#                           'content '
#                           'de '
#                           'la '
#                           'prestation '
#                           'que '
#                           'vous '
#                           'offrez '
#                           '? '
#                           'Ils '
#                           'sont '
#                           'satisfaits '
#                           'eux '
#                           'aussi '
#                           'des '
#                           'plages '
#                           "d'ouverture "
#                           'et '
#                           'des '
#                           'types '
#                           'de '
#                           'filières '
#                           'que '
#                           'vous '
#                           'leur '
#                           'proposez '
#                           '?',
#                   'tokens': [ 50814,
#                               10802,
#                               18935,
#                               2701,
#                               368,
#                               635,
#                               16305,
#                               399,
#                               631,
#                               2630,
#                               766,
#                               17693,
#                               2506,
#                               17979,
#                               4900,
#                               5519,
#                               1001,
#                               82,
#                               22648,
#                               6212,
#                               730,
#                               499,
#                               1660,
#                               274,
#                               6,
#                               43315,
#                               540,
#                               1030,
#                               730,
#                               3467,
#                               368,
#                               1387,
#                               39408,
#                               631,
#                               2630,
#                               9580,
#                               17421,
#                               89,
#                               2506,
#                               51164]},
#                 { 'avg_logprob': -0.23453645408153534,
#                   'compression_ratio': 1.7288732394366197,
#                   'end': 21.0,
#                   'id': 5,
#                   'no_speech_prob': 0.022877629846334457,
#                   'seek': 0,
#                   'start': 16.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Les '
#                           'clients '
#                           'sont '
#                           'hyper '
#                           'satisfaits, '
#                           'je '
#                           'sais '
#                           'aussi '
#                           'que '
#                           'mes '
#                           'agences '
#                           'sont '
#                           'vraiment '
#                           'satisfaites '
#                           'de '
#                           'venir '
#                           'travailler '
#                           'ici '
#                           'tous '
#                           'les '
#                           'matins.',
#                   'tokens': [ 51164,
#                               6965,
#                               6982,
#                               4900,
#                               9848,
#                               5519,
#                               1001,
#                               82,
#                               11,
#                               1506,
#                               11757,
#                               6212,
#                               631,
#                               3813,
#                               623,
#                               2667,
#                               4900,
#                               8322,
#                               5519,
#                               1001,
#                               279,
#                               368,
#                               20817,
#                               30968,
#                               11575,
#                               8317,
#                               1512,
#                               3803,
#                               1292,
#                               13,
#                               51414]},
#                 { 'avg_logprob': -0.23635229027789573,
#                   'compression_ratio': 1.6007751937984496,
#                   'end': 24.0,
#                   'id': 6,
#                   'no_speech_prob': 0.10796353220939636,
#                   'seek': 2100,
#                   'start': 22.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Bonjour '
#                           'à '
#                           'tous '
#                           'les '
#                           'deux '
#                           '!',
#                   'tokens': [ 50414,
#                               25431,
#                               1531,
#                               8317,
#                               1512,
#                               8208,
#                               2298,
#                               50514]},
#                 { 'avg_logprob': -0.23635229027789573,
#                   'compression_ratio': 1.6007751937984496,
#                   'end': 29.0,
#                   'id': 7,
#                   'no_speech_prob': 0.10796353220939636,
#                   'seek': 2100,
#                   'start': 24.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Dites-nous '
#                           'en '
#                           'quoi '
#                           'le '
#                           'service '
#                           'offert '
#                           'par '
#                           'cette '
#                           'déchetterie '
#                           'vous '
#                           'aide '
#                           'au '
#                           'quotidien '
#                           'dans '
#                           'votre '
#                           'métier '
#                           '?',
#                   'tokens': [ 50514,
#                               413,
#                               3324,
#                               12,
#                               47008,
#                               465,
#                               11714,
#                               476,
#                               2643,
#                               2626,
#                               83,
#                               971,
#                               5550,
#                               2795,
#                               339,
#                               27296,
#                               414,
#                               2630,
#                               40890,
#                               1609,
#                               44017,
#                               1053,
#                               2680,
#                               10087,
#                               20275,
#                               811,
#                               2506,
#                               50764]},
#                 { 'avg_logprob': -0.23635229027789573,
#                   'compression_ratio': 1.6007751937984496,
#                   'end': 36.0,
#                   'id': 8,
#                   'no_speech_prob': 0.10796353220939636,
#                   'seek': 2100,
#                   'start': 29.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'On '
#                           'est '
#                           'spécialisé '
#                           'dans '
#                           'la '
#                           'rénovation, '
#                           'donc '
#                           'ce '
#                           'qui '
#                           'nous '
#                           'intéresse '
#                           "c'est "
#                           'de '
#                           'pouvoir '
#                           'tout '
#                           'mélanger '
#                           'et '
#                           'venir '
#                           'ici '
#                           'faire '
#                           'le '
#                           'tri.',
#                   'tokens': [ 50764,
#                               1282,
#                               871,
#                               34141,
#                               22118,
#                               2680,
#                               635,
#                               3960,
#                               4185,
#                               399,
#                               11,
#                               5926,
#                               1769,
#                               1956,
#                               4666,
#                               18555,
#                               22603,
#                               269,
#                               6,
#                               377,
#                               368,
#                               14874,
#                               3486,
#                               41953,
#                               3176,
#                               1030,
#                               20817,
#                               11575,
#                               4865,
#                               476,
#                               1376,
#                               13,
#                               51114]},
#                 { 'avg_logprob': -0.23635229027789573,
#                   'compression_ratio': 1.6007751937984496,
#                   'end': 41.0,
#                   'id': 9,
#                   'no_speech_prob': 0.10796353220939636,
#                   'seek': 2100,
#                   'start': 36.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Et '
#                           'un '
#                           'gain '
#                           'de '
#                           'temps '
#                           'énorme '
#                           'de '
#                           'pouvoir '
#                           'recharger '
#                           'nos '
#                           'camions, '
#                           'racheter.',
#                   'tokens': [ 51114,
#                               3790,
#                               517,
#                               6052,
#                               368,
#                               8827,
#                               27982,
#                               68,
#                               368,
#                               14874,
#                               319,
#                               48942,
#                               3269,
#                               1945,
#                               626,
#                               11,
#                               367,
#                               608,
#                               2398,
#                               13,
#                               51364]},
#                 { 'avg_logprob': -0.23635229027789573,
#                   'compression_ratio': 1.6007751937984496,
#                   'end': 44.0,
#                   'id': 10,
#                   'no_speech_prob': 0.10796353220939636,
#                   'seek': 2100,
#                   'start': 41.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Et '
#                           'oui '
#                           'parce '
#                           'que '
#                           'cette '
#                           'déchetterie '
#                           'est '
#                           'partagée '
#                           'entre '
#                           'Point '
#                           'P '
#                           'et '
#                           'la '
#                           'plateforme '
#                           '?',
#                   'tokens': [ 51364,
#                               3790,
#                               14367,
#                               6992,
#                               631,
#                               5550,
#                               2795,
#                               339,
#                               27296,
#                               414,
#                               871,
#                               644,
#                               559,
#                               3856,
#                               3962,
#                               12387,
#                               430,
#                               1030,
#                               635,
#                               5924,
#                               44562,
#                               2506,
#                               51514]},
#                 { 'avg_logprob': -0.21928506967972736,
#                   'compression_ratio': 1.752442996742671,
#                   'end': 51.0,
#                   'id': 11,
#                   'no_speech_prob': 0.1981341540813446,
#                   'seek': 4400,
#                   'start': 44.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Tout '
#                           'à '
#                           'fait '
#                           'oui, '
#                           "c'est "
#                           'très '
#                           'compétitif '
#                           'puisque '
#                           'comme '
#                           'il '
#                           'y '
#                           'a '
#                           'des '
#                           'parties '
#                           'qui '
#                           'sont '
#                           'gratuites.',
#                   'tokens': [ 50364,
#                               20453,
#                               1531,
#                               3887,
#                               14367,
#                               11,
#                               269,
#                               6,
#                               377,
#                               5732,
#                               715,
#                               4051,
#                               270,
#                               351,
#                               28090,
#                               5173,
#                               1930,
#                               288,
#                               257,
#                               730,
#                               8265,
#                               1956,
#                               4900,
#                               38342,
#                               279,
#                               13,
#                               50714]},
#                 { 'avg_logprob': -0.21928506967972736,
#                   'compression_ratio': 1.752442996742671,
#                   'end': 56.0,
#                   'id': 12,
#                   'no_speech_prob': 0.1981341540813446,
#                   'seek': 4400,
#                   'start': 53.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'On '
#                           'utilise '
#                           'beaucoup '
#                           'parce '
#                           'que '
#                           'ça '
#                           'nous '
#                           'aide '
#                           'à '
#                           'être '
#                           'rapide, '
#                           'efficace.',
#                   'tokens': [ 50814,
#                               1282,
#                               39475,
#                               8796,
#                               6992,
#                               631,
#                               2788,
#                               4666,
#                               40890,
#                               1531,
#                               7418,
#                               5099,
#                               482,
#                               11,
#                               4703,
#                               617,
#                               13,
#                               50964]},
#                 { 'avg_logprob': -0.21928506967972736,
#                   'compression_ratio': 1.752442996742671,
#                   'end': 63.0,
#                   'id': 13,
#                   'no_speech_prob': 0.1981341540813446,
#                   'seek': 4400,
#                   'start': 56.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'On '
#                           'est '
#                           'très '
#                           'content '
#                           'parce '
#                           'que '
#                           "c'est "
#                           'facile '
#                           "d'accès "
#                           'et '
#                           'parce '
#                           'que '
#                           "c'est "
#                           'ouvert '
#                           "jusqu'à "
#                           '20h '
#                           'le '
#                           'soir, '
#                           'ça '
#                           'nous '
#                           'aide '
#                           'beaucoup '
#                           'au '
#                           'niveau '
#                           'de '
#                           "l'organisation "
#                           'et '
#                           'tout '
#                           'ça.',
#                   'tokens': [ 50964,
#                               1282,
#                               871,
#                               5732,
#                               2701,
#                               6992,
#                               631,
#                               269,
#                               6,
#                               377,
#                               23670,
#                               274,
#                               6,
#                               8476,
#                               3645,
#                               1030,
#                               6992,
#                               631,
#                               269,
#                               6,
#                               377,
#                               47683,
#                               20340,
#                               6,
#                               1467,
#                               945,
#                               71,
#                               476,
#                               27105,
#                               11,
#                               2788,
#                               4666,
#                               40890,
#                               8796,
#                               1609,
#                               19144,
#                               368,
#                               287,
#                               6,
#                               12372,
#                               7623,
#                               1030,
#                               3486,
#                               2788,
#                               13,
#                               51314]},
#                 { 'avg_logprob': -0.21928506967972736,
#                   'compression_ratio': 1.752442996742671,
#                   'end': 67.0,
#                   'id': 14,
#                   'no_speech_prob': 0.1981341540813446,
#                   'seek': 4400,
#                   'start': 63.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           "C'est "
#                           'très '
#                           'important '
#                           'de '
#                           'faire '
#                           'le '
#                           'tri '
#                           'pour '
#                           "l'avenir, "
#                           'pour '
#                           'la '
#                           'planète.',
#                   'tokens': [ 51314,
#                               383,
#                               6,
#                               377,
#                               5732,
#                               1021,
#                               368,
#                               4865,
#                               476,
#                               1376,
#                               2016,
#                               287,
#                               6,
#                               4940,
#                               347,
#                               11,
#                               2016,
#                               635,
#                               1393,
#                               22279,
#                               13,
#                               51514]},
#                 { 'avg_logprob': -0.21928506967972736,
#                   'compression_ratio': 1.752442996742671,
#                   'end': 72.0,
#                   'id': 15,
#                   'no_speech_prob': 0.1981341540813446,
#                   'seek': 4400,
#                   'start': 67.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'En '
#                           'plus '
#                           'maintenant '
#                           'on '
#                           'a '
#                           'une '
#                           'obligation '
#                           'au '
#                           'niveau '
#                           'de '
#                           'nos '
#                           'clients '
#                           'depuis '
#                           'plus '
#                           "d'un "
#                           'an '
#                           'maintenant '
#                           'de '
#                           'présenter '
#                           'le '
#                           'traitement '
#                           'des '
#                           'déchets.',
#                   'tokens': [ 51514,
#                               2193,
#                               1804,
#                               14817,
#                               322,
#                               257,
#                               2251,
#                               20326,
#                               1609,
#                               19144,
#                               368,
#                               3269,
#                               6982,
#                               16062,
#                               1804,
#                               274,
#                               6,
#                               409,
#                               364,
#                               14817,
#                               368,
#                               11761,
#                               14278,
#                               476,
#                               22538,
#                               1712,
#                               730,
#                               2795,
#                               339,
#                               1385,
#                               13,
#                               51764]},
#                 { 'avg_logprob': -0.2470545885039539,
#                   'compression_ratio': 1.2347826086956522,
#                   'end': 74.0,
#                   'id': 16,
#                   'no_speech_prob': 0.00797014869749546,
#                   'seek': 7200,
#                   'start': 72.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Donc '
#                           "c'est "
#                           'très '
#                           'important '
#                           'pour '
#                           'nous.',
#                   'tokens': [ 50364,
#                               7477,
#                               269,
#                               6,
#                               377,
#                               5732,
#                               1021,
#                               2016,
#                               4666,
#                               13,
#                               50464]},
#                 { 'avg_logprob': -0.2470545885039539,
#                   'compression_ratio': 1.2347826086956522,
#                   'end': 79.0,
#                   'id': 17,
#                   'no_speech_prob': 0.00797014869749546,
#                   'seek': 7200,
#                   'start': 74.0,
#                   'temperature': 0.0,
#                   'text': ' '
#                           'Même '
#                           'la '
#                           'terre '
#                           "qu'avant "
#                           'ils '
#                           'ne '
#                           'prenaient '
#                           'pas, '
#                           'là '
#                           'du '
#                           'coup '
#                           'ils '
#                           'nous '
#                           'la '
#                           'prennent '
#                           'aussi '
#                           'pour '
#                           'pouvoir '
#                           'vider.',
#                   'tokens': [ 50464,
#                               42027,
#                               635,
#                               31815,
#                               421,
#                               6,
#                               35034,
#                               9047,
#                               408,
#                               659,
#                               629,
#                               1196,
#                               1736,
#                               11,
#                               3684,
#                               1581,
#                               8682,
#                               9047,
#                               4666,
#                               635,
#                               43149,
#                               17469,
#                               6212,
#                               2016,
#                               14874,
#                               371,
#                               1438,
#                               13,
#                               50714]}],
#   'text': ' Bonjour Patrick '
#           '! Bonjour ! Alors '
#           'vous êtes le '
#           'responsable de ce '
#           'centre de '
#           'collecte, comment '
#           "va l'activité ? "
#           "L'activité va "
#           'très bien, je '
#           'suis vraiment '
#           'satisfait de voir '
#           'les clients avec '
#           'le sourire. Vous '
#           'êtes content de '
#           'la prestation que '
#           'vous offrez ? Ils '
#           'sont satisfaits '
#           'eux aussi des '
#           'plages '
#           "d'ouverture et "
#           'des types de '
#           'filières que vous '
#           'leur proposez ? '
#           'Les clients sont '
#           'hyper satisfaits, '
#           'je sais aussi que '
#           'mes agences sont '
#           'vraiment '
#           'satisfaites de '
#           'venir travailler '
#           'ici tous les '
#           'matins. Bonjour à '
#           'tous les deux ! '
#           'Dites-nous en '
#           'quoi le service '
#           'offert par cette '
#           'déchetterie vous '
#           'aide au quotidien '
#           'dans votre métier '
#           '? On est '
#           'spécialisé dans '
#           'la rénovation, '
#           'donc ce qui nous '
#           "intéresse c'est "
#           'de pouvoir tout '
#           'mélanger et venir '
#           'ici faire le tri. '
#           'Et un gain de '
#           'temps énorme de '
#           'pouvoir recharger '
#           'nos camions, '
#           'racheter. Et oui '
#           'parce que cette '
#           'déchetterie est '
#           'partagée entre '
#           'Point P et la '
#           'plateforme ? Tout '
#           "à fait oui, c'est "
#           'très compétitif '
#           'puisque comme il '
#           'y a des parties '
#           'qui sont '
#           'gratuites. On '
#           'utilise beaucoup '
#           'parce que ça nous '
#           'aide à être '
#           'rapide, efficace. '
#           'On est très '
#           'content parce que '
#           "c'est facile "
#           "d'accès et parce "
#           "que c'est ouvert "
#           "jusqu'à 20h le "
#           'soir, ça nous '
#           'aide beaucoup au '
#           'niveau de '
#           "l'organisation et "
#           "tout ça. C'est "
#           'très important de '
#           'faire le tri pour '
#           "l'avenir, pour la "
#           'planète. En plus '
#           'maintenant on a '
#           'une obligation au '
#           'niveau de nos '
#           'clients depuis '
#           "plus d'un an "
#           'maintenant de '
#           'présenter le '
#           'traitement des '
#           'déchets. Donc '
#           "c'est très "
#           'important pour '
#           'nous. Même la '
#           "terre qu'avant "
#           'ils ne prenaient '
#           'pas, là du coup '
#           'ils nous la '
#           'prennent aussi '
#           'pour pouvoir '
#           'vider.'}

# %%
pprint(text_large["text"])
# Out:
# (' Bonjour Patrick ! Bonjour ! Alors vous êtes le responsable de ce centre de '
#  "collecte, comment va l'activité ? L'activité va très bien, je suis vraiment "
#  'satisfait de voir les clients avec le sourire. Vous êtes content de la '
#  'prestation que vous offrez ? Ils sont satisfaits eux aussi des plages '
#  "d'ouverture et des types de filières que vous leur proposez ? Les clients "
#  'sont hyper satisfaits, je sais aussi que mes agences sont vraiment '
#  'satisfaites de venir travailler ici tous les matins. Bonjour à tous les deux '
#  '! Dites-nous en quoi le service offert par cette déchetterie vous aide au '
#  'quotidien dans votre métier ? On est spécialisé dans la rénovation, donc ce '
#  "qui nous intéresse c'est de pouvoir tout mélanger et venir ici faire le tri. "
#  'Et un gain de temps énorme de pouvoir recharger nos camions, racheter. Et '
#  'oui parce que cette déchetterie est partagée entre Point P et la plateforme '
#  "? Tout à fait oui, c'est très compétitif puisque comme il y a des parties "
#  'qui sont gratuites. On utilise beaucoup parce que ça nous aide à être '
#  "rapide, efficace. On est très content parce que c'est facile d'accès et "
#  "parce que c'est ouvert jusqu'à 20h le soir, ça nous aide beaucoup au niveau "
#  "de l'organisation et tout ça. C'est très important de faire le tri pour "
#  "l'avenir, pour la planète. En plus maintenant on a une obligation au niveau "
#  "de nos clients depuis plus d'un an maintenant de présenter le traitement des "
#  "déchets. Donc c'est très important pour nous. Même la terre qu'avant ils ne "
#  'prenaient pas, là du coup ils nous la prennent aussi pour pouvoir vider.')

# %%
pprint(text_base["text"])
# Out:
# (' Bonjour Patrick ! Bonjour ! Alors vous êtes le responsable de ce centre de '
#  "collecte, comment va l'activité ? La activité va très bien, c'est vraiment "
#  "satisfait et le val et client avec le sourire. C'est content de la "
#  "prestation que vous offrez, ils sont satisfaits aussi des plages d'ouverture "
#  'et des types de filières que vous leur proposer. Les clients sont hyper '
#  'satisfaits, je sais aussi que mes agents sont vraiment satisfaits de venir '
#  'travailler ici tous les matins. Bonjour à tous les deux. Dis-t-nous en quoi '
#  'le service au fer par cette déchétrie vous aide aux clients dans votre '
#  "métier ? On est spécialisé dans la innovation, ce qui nous intéresse, c'est "
#  'de pouvoir tout mélanger et puis venir ici faire le tri et un gain de temps '
#  'énorme, de pouvoir recharger nos camions, racheter. Et oui parce que cette '
#  'déchétrie est partagée entre point P et la plateforme ? Tout à fait, oui, '
#  "voilà. C'est très convétitif, puisque comme il y a des parties qui sont "
#  'gratuite. On utilise beaucoup parce que ça nous aide à être rapide et '
#  "efficace, on est très content parce que c'est facile d'accé et parce que ça "
#  "veut être tard au jour que l'avant-à-avant le soir, ça nous aide beaucoup au "
#  "niveau de organisation et tout ça. C'est très important de faire le tri pour "
#  "l'avenir, pour la planète. En plus maintenant, on a une obligation au niveau "
#  "de nos clients depuis plus d'un an, maintenant on a présenté le traitement "
#  "des déchets. Donc c'est très important pour nous. Même la terre qui n'a pas "
#  'de coup, ils nous le prennent aussi pour voir le vidéo.')

# %%
print(
    f"Model is {'multilingual' if model.is_multilingual else 'English-only'} "
    f"and has {sum(np.prod(p.shape) for p in model.parameters()):,} parameters."
)
# Out:
# Model is multilingual and has 1,541,384,960 parameters.

# %% [markdown]
# ## Gradio webapp

# %%
def transcribe_audio(audio_file):
    """
    Gradio function
    """
    model = whisper.load_model("base")
    result = model.transcribe(audio_file)

    return result["text"]

# %%
audio_input = gr.inputs.Audio(source="upload", type="filepath")
output_text = gr.outputs.Textbox()

logo = "https://github.com/retkowsky/images/blob/master/logoazureCV.png?raw=true"
image = "<center> <img src= {} width=50px></center>".format(logo)

webapp = gr.Interface(
    fn=transcribe_audio,
    inputs=audio_input,
    outputs=output_text,
    description=image,
    title="Audio Transcription App with Open AI Whisper",
)

# %%
webapp.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://abb6dc81d481f2542c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://abb6dc81d481f2542c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
